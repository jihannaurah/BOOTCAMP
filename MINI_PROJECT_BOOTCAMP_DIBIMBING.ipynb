# %% [markdown]
# <a href="https://colab.research.google.com/github/jihannaurah/BOOTCAMP/blob/main/MINI_PROJECT_BOOTCAMP_DIBIMBING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('data.csv', encoding='latin1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# DATA QUALITY CHECK

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(5268)

# %%
df[df.duplicated()]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 517       536409     21866        UNION JACK FLAG LUGGAGE TAG         1
# 527       536409     22866      HAND WARMER SCOTTY DOG DESIGN         1
# 537       536409     22900    SET 2 TEA TOWELS I LOVE LONDON          1
# 539       536409     22111       SCOTTIE DOG HOT WATER BOTTLE         1
# 555       536412     22327  ROUND SNACK BOXES SET OF 4 SKULLS         1
# ...          ...       ...                                ...       ...
# 541675    581538     22068        BLACK PIRATE TREASURE CHEST         1
# 541689    581538     23318     BOX OF 6 MINI VINTAGE CRACKERS         1
# 541692    581538     22992             REVOLVER WOODEN RULER          1
# 541699    581538     22694                       WICKER STAR          1
# 541701    581538     23343       JUMBO BAG VINTAGE CHRISTMAS          1
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 517     12/1/2010 11:45       1.25     17908.0  United Kingdom
# 527     12/1/2010 11:45       2.10     17908.0  United Kingdom
# 537     12/1/2010 11:45       2.95     17908.0  United Kingdom
# 539     12/1/2010 11:45       4.95     17908.0  United Kingdom
# 555     12/1/2010 11:49       2.95     17920.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541675  12/9/2011 11:34       0.39     14446.0  United Kingdom
# 541689  12/9/2011 11:34       2.49     14446.0  United Kingdom
# 541692  12/9/2011 11:34       1.95     14446.0  United Kingdom
# 541699  12/9/2011 11:34       2.10     14446.0  United Kingdom
# 541701  12/9/2011 11:34       2.08     14446.0  United Kingdom
#
# [5268 rows x 8 columns]

# %% [markdown]
# DATA CLEANING

# %%
df = df.drop_duplicates()

# %%
df = df.dropna(subset=['CustomerID'])

# %%
print(df.shape)
# Out:
# (401604, 8)

# %%
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
df = df.reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401604 entries, 0 to 401603
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    401604 non-null  object
#  1   StockCode    401604 non-null  object
#  2   Description  401604 non-null  object
#  3   Quantity     401604 non-null  int64
#  4   InvoiceDate  401604 non-null  object
#  5   UnitPrice    401604 non-null  float64
#  6   CustomerID   401604 non-null  float64
#  7   Country      401604 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 24.5+ MB

# %% [markdown]
# FILTERING "QUANTITY, UNITPRICE"

# %%
df = df[df['Quantity'] > 0]

# %%
df = df[df['UnitPrice'] > 0]

# %%
df = df.reset_index(drop=True)

# %%
print("Hasil:")
print(df.shape)
# Out:
# Hasil:
# (392692, 8)

# %%
print("\ninfo detail:")
df.info()
# Out:
# info detail:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392692 entries, 0 to 392691
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    392692 non-null  object
#  1   StockCode    392692 non-null  object
#  2   Description  392692 non-null  object
#  3   Quantity     392692 non-null  int64
#  4   InvoiceDate  392692 non-null  object
#  5   UnitPrice    392692 non-null  float64
#  6   CustomerID   392692 non-null  float64
#  7   Country      392692 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 24.0+ MB

# %% [markdown]
# MASKING

# %%
df['CustomerID'] = df['CustomerID'].astype(int).astype(str)
df['CustomerID'] = df['CustomerID'].str[:2] + '***'

df['StockCode'] = df['StockCode'].astype(str)
df['StockCode'] = df['StockCode'].str[:2] + '***'

print("Data Masking")
df.sample(20)
# Out:
# Data Masking
#        InvoiceNo StockCode                         Description  Quantity  \
# 348344    577121     22***                      POPCORN HOLDER        12
# 384575    580727     22***                LIPSTICK PEN FUSCHIA        12
# 191886    561195     22***           BOUDOIR SQUARE TISSUE BOX         4
# 375358    579846     22***     PAPER CHAIN KIT 50'S CHRISTMAS         18
# 235130    566285     84***    ENCHANTED BIRD COATHANGER 5 HOOK         2
# 218155    564199     22***     METAL SIGN TAKE IT OR LEAVE IT          3
# 254549    568193     22***     METAL SIGN NEIGHBOURHOOD WITCH          5
# 268820    569546     23***      TRIPLE HOOK ANTIQUE IVORY ROSE         1
# 346       536401     20***             STRAWBERRY BATH SPONGE          1
# 99497     549313     22***              LUNCH BAG SUKI DESIGN         30
# 9254      537421     22***    STAR WOODEN CHRISTMAS DECORATION         5
# 243539    567178     21***            LOVE BUILDING BLOCK WORD         2
# 315742    574075     20***          ASSORTED COLOUR MINI CASES        19
# 61994     544724     22***     NATURAL SLATE CHALKBOARD LARGE          3
# 244732    567213     22***              HAND WARMER OWL DESIGN         5
# 385305    580771     22***        SMALL RED BABUSHKA NOTEBOOK          2
# 160241    557262     23***              REGENCY MILK JUG PINK          1
# 276674    570246     21***                PAINTED PINK RABBIT          1
# 156838    556815     21***            BATH BUILDING BLOCK WORD         6
# 368423    579087     22***  3 PIECE SPACEBOY COOKIE CUTTER SET         6
#
#              InvoiceDate  UnitPrice CustomerID         Country
# 348344  11/17/2011 18:29       0.85      12***          France
# 384575   12/5/2011 17:17       0.83      14***  United Kingdom
# 191886   7/25/2011 13:57       0.39      14***  United Kingdom
# 375358  11/30/2011 16:22       2.95      12***  United Kingdom
# 235130   9/11/2011 14:51       4.65      13***  United Kingdom
# 218155   8/23/2011 17:31       2.95      13***  United Kingdom
# 254549   9/25/2011 14:37       2.10      17***  United Kingdom
# 268820   10/4/2011 16:39       3.29      15***  United Kingdom
# 346      12/1/2010 11:21       1.25      15***  United Kingdom
# 99497      4/8/2011 9:45       1.65      12***       Australia
# 9254     12/6/2010 15:25       0.85      17***  United Kingdom
# 243539   9/18/2011 14:08       6.25      17***  United Kingdom
# 315742   11/2/2011 15:33       6.35      16***  United Kingdom
# 61994    2/23/2011 10:46       4.95      15***  United Kingdom
# 244732   9/19/2011 11:04       2.10      14***  United Kingdom
# 385305   12/6/2011 10:58       0.21      16***  United Kingdom
# 160241   6/19/2011 10:55       3.25      16***  United Kingdom
# 276674   10/9/2011 16:22       0.85      16***  United Kingdom
# 156838    6/15/2011 8:36       5.95      14***  United Kingdom
# 368423  11/28/2011 10:35       2.10      13***  United Kingdom

# %% [markdown]
# **DATA DICTIONARY**
# | Nama Kolom | Tipe | Penjelasan Singkat | Contohnya |
# | :--- | :--- | :--- | :--- |
# | **InvoiceNo** | Teks | Kode transaksi. Kalau ada huruf 'C' di depan, berarti itu barang yang dicancel/retur. | 536365 |
# | **StockCode** | Teks | Kode buat tiap barang. (masking). | 85*** |
# | **Description** | Teks | Nama barang atau penjelasan produk yang dibeli pelanggan. | BOX OF 6 MINI VINTAGE CRACKERS... |
# | **Quantity** | Angka | Jumlah barang yang dibeli. Udah di filter jadi cuma angka yang di atas 0. | 6 |
# | **InvoiceDate** | Teks | Tanggal sama jam kapan transaksi itu terjadi. | 12/1/2010 8:26 |
# | **UnitPrice** | Desimal | Harga satu barang dalam Poundsterling (£). | 2.55 |
# | **CustomerID** | Teks | ID Pelanggan. Udah di sensor (masking) juga buat jaga data sensitif. | 17*** |
# | **Country** | Teks | Negara tempat belanja atau asal pelanggannya. | United Kingdom |

# %%
df.to_csv('Online_Retail_E-Commerce.csv', index=False)
df.to_excel('Online_Retail_E-Commerce.xlsx', index=False)
print('Tuntas!')
# Out:
# Tuntas!
